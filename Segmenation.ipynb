# %% [markdown]
# ###### Importing tabular data from  Wikipedia

# %%
import pandas as pd

url='https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'

df=pd.read_html(url, header=0)[0]

df.head()
# Out:
#   Postal Code           Borough               Neighborhood
# 0         M1A      Not assigned               Not assigned
# 1         M2A      Not assigned               Not assigned
# 2         M3A        North York                  Parkwoods
# 3         M4A        North York           Victoria Village
# 4         M5A  Downtown Toronto  Regent Park, Harbourfront

# %% [markdown]
# ###### Filtering out the 'Not assigned' Boroughs from the DF

# %%
df=df[df['Borough']!='Not assigned']
print(df.head())
print(df.shape)
# Out:
#   Postal Code           Borough                                 Neighborhood
# 2         M3A        North York                                    Parkwoods
# 3         M4A        North York                             Victoria Village
# 4         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 5         M6A        North York             Lawrence Manor, Lawrence Heights
# 6         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
# (103, 3)

# %% [markdown]
# ###### Assigning Borough value to Neighborhood if the Neiberhood value is 'Not assigned'

# %%
df.loc[df.Neighborhood == "Not assigned", "Neighborhood"] = df['Borough']

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#   Postal Code           Borough                                 Neighborhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %% [markdown]
# ###### Importing geospatial data from http://cocl.us/Geospatial_data and merging with the Postalcode / Neighborhood df

# %%
dfll=pd.read_csv("http://cocl.us/Geospatial_data")
dfpost=df.merge(dfll, on='Postal Code', how ='left')

# %%
dfpost.head()
# Out:
#   Postal Code           Borough                                 Neighborhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.753259 -79.329656
# 1  43.725882 -79.315572
# 2  43.654260 -79.360636
# 3  43.718518 -79.464763
# 4  43.662301 -79.389494

# %% [markdown]
# ###### Installing Folium

# %%
! pip install folium
# Out:
# Requirement already satisfied: folium in e:\softwares\anaconda\lib\site-packages (0.11.0)
# Requirement already satisfied: requests in e:\softwares\anaconda\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: numpy in e:\softwares\anaconda\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: jinja2>=2.9 in e:\softwares\anaconda\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: branca>=0.3.0 in e:\softwares\anaconda\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in e:\softwares\anaconda\lib\site-packages (from requests->folium) (1.25.8)
# Requirement already satisfied: idna<2.9,>=2.5 in e:\softwares\anaconda\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in e:\softwares\anaconda\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in e:\softwares\anaconda\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: MarkupSafe>=0.23 in e:\softwares\anaconda\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)

# %%
import folium

# %%
latitude = 43.6529
longitude = -79.3849

# %% [markdown]
# ###### Creating Maps with Neighborhood cluster

# %%
from folium import plugins

# let's start again with a clean copy of the map of San Francisco
tor_map = folium.Map(location = [latitude, longitude], zoom_start = 12)

# instantiate a mark cluster object for the incidents in the dataframe
hood = plugins.MarkerCluster().add_to(tor_map)

# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(dfpost.Latitude, dfpost.Longitude, dfpost.Neighborhood):
    folium.Marker(
        location=[lat, lng],
        icon=None,
        popup=label,
    ).add_to(hood)

# display map
tor_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
